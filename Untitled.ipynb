# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import seaborn as sns
#       3 import numpy as np
#       4 import pandas as pd
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# Ejemplo: tiempos promedio de ejecución (segundos)
algoritmos = ['Burbuja', 'Insercion', 'Quicksort', 'MergeSort', 'HeapSort']
tamaños = [100, 1000, 10000]

# Simulación de resultados (fila: algoritmo, columna: tamaño)
tiempos = np.array([
    [0.001, 0.12, 12],
    [0.0008, 0.1, 10],
    [0.00005, 0.005, 0.1],
    [0.00007, 0.006, 0.12],
    [0.00006, 0.0055, 0.11]
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 6
#       3 tamaños = [100, 1000, 10000]
#       5 # Simulación de resultados (fila: algoritmo, columna: tamaño)
# ----> 6 tiempos = np.array([
#       7     [0.001, 0.12, 12],
#       8     [0.0008, 0.1, 10],
#       9     [0.00005, 0.005, 0.1],
#      10     [0.00007, 0.006, 0.12],
#      11     [0.00006, 0.0055, 0.11]
#      12 ])
#
# NameError: name 'np' is not defined
